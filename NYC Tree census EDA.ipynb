# %% [markdown]
# # Tree Census EDA

# %% [markdown]
# In this notebook we will exploring the NYC tree Census Dataset from 2015

# %%
import pandas as pd

# %% [markdown]
# We start by importing the dataset by reading in the csv file and assigning it to a variable.

# %%
tree_census = pd.read_csv("/Users/chinmaydande/Desktop/Courses/Python Coding/DataAnalysis/data/2015_Street_Tree_Census_-_Tree_Data_20240618.csv")

# %%
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   155433    217978  08/18/2015        25           0   OnCurb  Alive
# 683784   183795    348185  08/29/2015         7           0   OnCurb  Alive
# 683785   166161    401670  08/22/2015        12           0   OnCurb  Alive
# 683786   184028    504204  08/29/2015         9           0   OnCurb  Alive
# 683787   200607    306527  09/03/2015        23           0   OnCurb  Alive
#
# ...

# %% [markdown]
# Checking the columns of the dataset

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %% [markdown]
# Checking for null values

# %%
tree_census.isna().sum()
# Out:
# tree_id                  0
# block_id                 0
# created_at               0
# tree_dbh                 0
# stump_diam               0
# curb_loc                 0
# status                   0
# health               31616
# spc_latin            31619
# spc_common           31619
# steward             519438
# guards              603922
# sidewalk             31616
# user_type                0
# problems            457944
# root_stone               0
# root_grate               0
# root_other               0
# trunk_wire               0
# trnk_light               0
# trnk_other               0
# brch_light               0
# brch_shoe                0
# brch_other               0
# address                  0
# postcode                 0
# zip_city                 0
# community board          0
# borocode                 0
# borough                  0
# cncldist                 0
# st_assem                 0
# st_senate                0
# nta                      0
# ...

# %% [markdown]
# We can see above that there ares several columns with null values

# %%
tree_census.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000
#
#             postcode  community board       borocode       cncldist  \
# count  683788.000000    683788.000000  683788.000000  683788.000000
# mean    10916.246044       343.505404       3.358500      29.943181
# std       651.553364       115.740601       1.166746      14.328531
# min        83.000000       101.000000       1.000000       1.000000
# ...

# %% [markdown]
# Above we get overview of summary stats of the dataset

# %%
tree_census.dtypes
# Out:
# tree_id               int64
# block_id              int64
# created_at           object
# tree_dbh              int64
# stump_diam            int64
# curb_loc             object
# status               object
# health               object
# spc_latin            object
# spc_common           object
# steward              object
# guards               object
# sidewalk             object
# user_type            object
# problems             object
# root_stone           object
# root_grate           object
# root_other           object
# trunk_wire           object
# trnk_light           object
# trnk_other           object
# brch_light           object
# brch_shoe            object
# brch_other           object
# address              object
# postcode              int64
# zip_city             object
# community board       int64
# borocode              int64
# borough              object
# cncldist              int64
# st_assem              int64
# st_senate             int64
# ...

# %% [markdown]
# This is a list of common data types in the dataset (float, objects and integers)

# %%
tree_census.hist(bins=1000, figsize=(30,20))
# Out:
# array([[<Axes: title={'center': 'tree_id'}>,
#         <Axes: title={'center': 'block_id'}>,
#         <Axes: title={'center': 'tree_dbh'}>,
#         <Axes: title={'center': 'stump_diam'}>],
#        [<Axes: title={'center': 'postcode'}>,
#         <Axes: title={'center': 'community board'}>,
#         <Axes: title={'center': 'borocode'}>,
#         <Axes: title={'center': 'cncldist'}>],
#        [<Axes: title={'center': 'st_assem'}>,
#         <Axes: title={'center': 'st_senate'}>,
#         <Axes: title={'center': 'boro_ct'}>,
#         <Axes: title={'center': 'latitude'}>],
#        [<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'x_sp'}>,
#         <Axes: title={'center': 'y_sp'}>,
#         <Axes: title={'center': 'council district'}>],
#        [<Axes: title={'center': 'census tract'}>,
#         <Axes: title={'center': 'bin'}>, <Axes: title={'center': 'bbl'}>,
#         <Axes: >]], dtype=object)

# %% [markdown]
# Here are some histograms of how the data is distrbuted in the X and Y axis.

# %%
big_trees = tree_census[tree_census['tree_dbh']>50]

# %%
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter',x='tree_id',y='tree_dbh', figsize=(20,10))
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>

# %% [markdown]
# The scatterplot above displays of tree breast height (tbh)

# %%
pd.DataFrame(tree_census['spc_latin'].value_counts()).plot(kind='bar', figsize=(40,30))
# Out:
# <Axes: xlabel='spc_latin'>

# %% [markdown]
# These are the most common latin names of the trees

# %%
tree_census['steward'].value_counts()
# Out:
# steward
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: count, dtype: int64

# %% [markdown]
# Above lists the steward of the trees

# %%
tree_census['sidewalk'].value_counts()
# Out:
# sidewalk
# NoDamage    464978
# Damage      187194
# Name: count, dtype: int64

# %% [markdown]
# The information above pertains how sidewalks either damage or have no damage on the trees.

# %%
stumps = tree_census[tree_census['status']=='Stump']
stumps
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 37       211205    302080  09/09/2015         0          16   OnCurb  Stump
# 239      203597    301947  09/04/2015         0          15   OnCurb  Stump
# 641      179766    230466  08/27/2015         0          30   OnCurb  Stump
# 644      180619    348834  08/27/2015         0          10   OnCurb  Stump
# 646      208828    107238  09/08/2015         0          15   OnCurb  Stump
# ...         ...       ...         ...       ...         ...      ...    ...
# 683348   152836    217718  08/17/2015         0          13   OnCurb  Stump
# 683686   191219    321689  08/31/2015         0          25   OnCurb  Stump
# 683695   170888    231931  08/24/2015         0           5   OnCurb  Stump
# 683697   177922    410634  08/26/2015         0          17   OnCurb  Stump
# 683699   172660    349995  08/25/2015         0           4   OnCurb  Stump
#
# ...

# %% [markdown]
# Status of the trees with stumps.

# %%
deads = tree_census[tree_census['status']=='Dead']
deads
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam        curb_loc  \
# 57       187807    506266  08/29/2015         0           0          OnCurb
# 196      208322    222858  09/07/2015        10           0          OnCurb
# 209      209058    415850  09/08/2015         6           0          OnCurb
# 266      210544    216081  09/08/2015         6           0          OnCurb
# 285      188609    107627  08/30/2015         9           0          OnCurb
# ...         ...       ...         ...       ...         ...             ...
# 682816   184342    505510  08/29/2015        11           0          OnCurb
# 682823   155430    217978  08/18/2015         2           0          OnCurb
# 683346   156566    514686  08/18/2015        10           0          OnCurb
# 683693   156162    108193  08/18/2015         3           0  OffsetFromCurb
# 683698   193791    208850  09/01/2015         3           0          OnCurb
#
# ...

# %% [markdown]
# Trees that have the status of dead.

# %%
tree_problems = tree_census[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %% [markdown]
# Trees that have problems based on characteristics.
